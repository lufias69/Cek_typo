# %%
import json
def getData(alamat):
    lineList = list()
    with open(alamat, encoding = "ISO-8859-1") as f:
        for line in f:
            lineList.append(line.rstrip('\n'))
    return lineList

# %%
# k = getData("last_use_k.txt")
# r = getData("last_use_r.txt")
# dict_ =dict()
# for a, b in zip(k, r):
#     dict_.update( {a : b} )
# dict_

# %%
k = getData("_kata_.txt")
r = getData("_replace_.txt")
dict_ =dict()
for a, b in zip(k, r):
    dict_.update( {a : b} )
dict_
# Out:
# {'aaamiinn': 'amin',
#  'aaamiin': 'amin',
#  'aaammiinn': 'amin',
#  'aaku': 'saya',
#  'aali': 'ali',
#  'aalspeeds': 'all speed',
#  'aamiinaoeoe': 'amin',
#  'aamiinn': 'amin',
#  'aanget': 'banget',
#  'aatau': 'atau',
#  'aaya': 'saya',
#  'abang2': 'abang',
#  'abiiss': 'habis',
#  'abiss': 'habis',
#  'abizz': 'habis',
#  'adaa': 'ada',
#  'adagak': 'ada tidak',
#  'adain': 'adakan',
#  'adl': 'adalah',
#  'adlah': 'adalah',
#  'adminnya': 'admin',
#  'admint': 'admin',
#  'adminwa': 'admin wa',
#  'aduuh': 'aduh',
#  'againaku': 'again aku',
#  'againtidak': 'again tidak',
#  'agakk': 'agak',
#  'agar': 'agar',
#  'agarr': 'agar',
#  'agenarenatiket': 'agen arena tiket',
#  'agencyberminat': 'agency berminat',
#  'agendomino': 'agen domino',
#  'agendominobanyakpromo': 'agen domino banyak promo',
#  'agenpoker': 'agen poker',
#  'agenpokertanpabot': 'agen poker tanpa bot',
#  'agenpokerterbaik': 'agen poker terbaik',
#  'agent': 'agen',
#  'agentiketmurah': 'agen tiket murah',
#  'agentiketpesawat': 'agen tiket pesawat',
#  'aherat': 'akhirat',
#  'ahkiratmu': 'akhirat',
#  'ahldllhh': 'adalah',
#  'ahzab': 'azab',
#  'airmata': 'air mata',
#  'dm': 'dm',
#  'ajadm': 'aja dm',
#  'ajaib': 'ajaib',
#  'ajaibb': 'ajaib',
#  'ajaiibb': 'ajaib',
#  'ajanga': 'jangan',
#  'ajibb': 'ajib',
#  'ajiib': 'ajib',
#  'akaak': 'kakak',
#  'akami': 'kami',
#  'akang': 'kakak',
#  'akau': 'kau',
#  'akeh': 'banyak',
#  'akh': 'akhir',
#  'akhir': 'akhir',
#  'akhiri': 'akhir',
#  'akhirnya': 'akhir',
#  'akhirnyaa': 'akhir',
#  'akkhhirrnyya': 'akhir',
#  'akkuu': 'aku',
#  'akoh': 'aku',
#  'akt': 'aktif',
#  'aktif': 'aktif',
#  'aktifada': 'aktif ada',
#  'aktifin': 'aktif',
#  'aktivitas': 'aktif',
#  'aku1': 'aku',
#  'akumau': 'aku mau',
#  'akungakak': 'aku tidak',
#  'akuu': 'aku',
#  'akuuyyu': 'aku',
#  'akuuyu': 'aku',
#  'akyu': 'aku',
#  'akyuu': 'aku',
#  'alaikum': 'alaikum',
#  'alamii': 'alami',
#  'alaminya': 'alami',
#  'alammii': 'alami',
#  'alatnya': 'alat',
#  'alatnyaa': 'alat',
#  'alatt': 'alat',
#  'alau': 'kalau',
#  'alesan': 'alasan',
#  'alfama': 'alfamart',
#  'alhadits': 'alhadist',
#  'alhasil': 'hasil',
#  'alhasill': 'hasil',
#  'allahhuma': 'allahumma',
#  'allahuma': 'allahumma',
#  'allhamdulillahh': 'alhamdulillah',
#  'allkita': 'alkitab',
#  'allatt': 'alat',
#  'allohunma': 'allahumma',
#  'allsh': 'all',
#  'alm': 'alm',
#  'alun2': 'alun',
#  'alwayss': 'always',
#  'alwsyss': 'always',
#  'amalibadah': 'amal ibadah',
#  'amann': 'aman',
#  'amatsih': 'ama ',
#  'amatt': 'amat',
#  'ambek': 'ambek',
#  'ambk': 'ambek',
#  'amiee': 'amin',
#  'amieenn': 'amin',
#  'amiinn': 'amin',
#  'aminnmba': 'amin mba',
#  'aminyaallah': 'amin',
#  'ammin': 'amin',
#  'amooreabogor': 'amoorea bogor',
#  'amooreaindonesia': 'amoorea indonesia',
#  'amooreawonosobo': 'amoorea wonosobo',
#  'ampug': 'ampuh',
#  'ampuhh': 'ampuh',
#  'ampunn': 'ampun',
#  'ampuuh': 'ampuh',
#  'ampuuhh': 'ampuh',
#  'ampuunn': 'ampuh',
#  'anakk': 'anak',
#  'anakuu': 'anak',
#  'andaa': 'anak',
#  'anggapaksisetiaji': 'anggapaksisetiaji',
#  'anginn': 'angin',
#  'ank2ku': 'anak',
#  'antvny': 'antv',
#  'apa2': 'apa',
#  'apaa': 'apa',
#  'apaalagii': 'apa',
#  'apain': 'apa',
#  'apalagi': 'apa',
#  'apalagii': 'apa',
#  'apalah': 'apa',
#  'apanya': 'apa',
#  'apapuee': 'apa',
#  'apapun': 'apa',
#  'apapunn': 'apa',
#  'apaseh': 'apa',
#  'apik': 'bagus',
#  'aplg': 'apalagi',
#  'apps': 'apps',
#  'appss': 'apps',
#  'apss': 'apps',
#  'arangg': 'arang',
#  'aransemennya': 'aransemen',
#  'aransement': 'aransemen',
#  'arap': 'arab',
#  'arasementnya': 'aransemen',
#  'arehh': 'arah',
#  'arenatiket': 'arena tiket',
#  'arenatiketindonesia': 'arena tiket indonesia',
#  'arquran': 'alquran',
#  'artinyaa': 'arti',
#  'artis2': 'arti',
#  'artisnya': 'artis',
#  'artiss': 'artis',
#  'artisse': 'astis',
#  'asek': 'asik',
#  'asiagame': 'asian games',
#  'asiagames': 'asian games',
#  'asiangames2018': 'asian games 2019',
#  'asikk': 'asik',
#  'aslii': 'asli',
#  'asline': 'asli',
#  'assalamu': 'assalamualaikum',
#  'assalamuallaikum': 'assalamualaikum',
#  'asyiikk': 'asik',
#  'asyik': 'asik',
#  'ataass': 'atas',
#  'atass': 'atas',
#  'ataua': 'atas',
#  'ataukah': 'atau',
#  'ataupun': 'atau',
#  'atauu': 'atau',
#  'atauwa': 'atau',
#  'atiku': 'hati',
#  'atmepic': 'atmepic',
#  'atmharga': 'atm harga',
#  'atmlegend': 'atm legend',
#  'atpukul': 'at pukul',
#  'att': 'at',
#  'awal2': 'awal',
#  'awall': 'awal',
#  'awallnyaa': 'awal',
#  'awalnqaa': 'awal',
#  'awalnya': 'awal',
#  'awalnyaa': 'awal',
#  'awards': 'award',
#  'awass': 'awas',
#  'awwallnyaa': 'awal',
#  'awwalnnyyaa': 'awal',
#  'ayoo': 'ayo',
#  'ayow': 'ayu',
#  'ayuu': 'ayu',
#  'baadan': 'badan',
#  'baangeet': 'banget',
#  'baanget': 'banget',
#  'baanyakk': 'banyak',
#  'baadaan': 'badan',
#  'baadann': 'badan',
#  'baaguss': 'bagus',
#  'baanggeet': 'banget',
#  'baanggett': 'banget',
#  'baannggett': 'banget',
#  'baanyak': 'banyak',
#  'baayar': 'bayar',
#  'baca2': 'baca',
#  'bacaa': 'baca',
#  'bacanya': 'baca',
#  'badaan': 'badan',
#  'badaann': 'badan',
#  'badaannya': 'badan',
#  'badan2': 'badan',
#  'badanann': 'badan',
#  'badanmn': 'badan',
#  'badann': 'badan',
#  'badannmuu': 'badan',
#  'badannya': 'badan',
#  'badannyaa': 'badan',
#  'baddan': 'badan',
#  'baddann': 'badan',
#  'badget': 'budget',
#  'bagaimna': 'bagaimana',
#  'baget': 'banget',
#  'bagian': 'bagian',
#  'bagusan': 'bagusan',
#  'bagusbagus': 'bagus',
#  'baguss': 'bagus',
#  'bahaan': 'bahan',
#  'bahwaa': 'bahwa',
#  'baiasa': 'biasa',
#  'baju2': 'baju',
#  'bajuu': 'baju',
#  'balek': 'balik',
#  'balekne': 'kembalikan',
#  'bales': 'balas',
#  'balesin': 'balasan',
#  'baleum': 'belum',
#  'balik': 'balik',
#  'baline': 'pulangnya',
#  'balm': 'belum',
#  'bandar33': 'bandar',
#  'bandar66': 'bandar',
#  'bandarceme': 'bandar ceme',
#  'bandarpoker': 'bandar poker',
#  'bandarpokerbanyakbonus': 'bandar poker banyak bonus',
#  'bandarpokerterpercaya': 'bandar poker terpercaya',
#  'bandingin': 'bangding',
#  'bandingkan': 'bandingkan',
#  'bandrolnya': 'bandrol',
#  'bandung2': 'bandung',
#  'bang': 'kakak',
#  'bangat': 'banget',
#  'bangeet': 'banget',
#  'bangeett': 'banget',
#  'banget': 'banget',
#  'bangetlangsung': 'banget langsung',
#  'bangets': 'banget',
#  'bangetsi': 'banget',
#  'bangetts': 'banget',
#  'bangett': 'banget',
#  'bangetytt': 'banget',
#  'banggeet': 'banget',
#  'banggett': 'banget',
#  'banguss': 'bagus',
#  'banjirlokasi': 'banjir lokasi',
#  'banngget': 'banget',
#  'banyaak': 'banyak',
#  'banyaakk': 'banyak',
#  'banyak': 'banyak',
#  'banyak0': 'banyak',
#  'banyak2': 'banyak',
#  'banyakin': 'banyak',
#  'banyakk': 'banyak',
#  'banyaknya': 'banyak',
#  'bapakku': 'bapak',
#  'baraguss': 'baragus',
#  'barakallah': 'barakallah',
#  'barang100': 'barang',
#  'barang2': 'barang',
#  'bariklana': 'beriklan',
#  'barokahi': 'barokah',
#  'barsama': 'bersama',
#  'barukalii': 'baru kali',
#  'baruu': 'baru',
#  'batikair': 'batik air',
#  'batreku': 'batrei',
#  'bawaan': 'bawa',
#  'bawahkubah': 'bawah kubah',
#  'bawain': 'bawa',
#  'banyang': 'nan',
#  'bayabgin': 'bayangkan',
#  'bayak': 'banyak',
#  'bayangin': 'bayangkan',
#  'bayaran': 'bayar',
#  'bayarin': 'bayar',
#  'bbaanggett': 'banget',
#  'bbaannggeett': 'banget',
#  'bbaannggett': 'banget',
#  'bebwrapa': 'beberapa',
#  'becomes': 'became',
#  'beebass': 'bebas',
#  'beekah': 'berkah',
#  'beeli': 'beli',
#  'beeraat': 'berat',
#  'beginian': 'begini',
#  'beginii': 'begini',
#  'bego': 'bodoh',
#  'begok': 'bodoh',
#  'begono': 'begini',
#  'beground': 'background',
#  'belakangcoba': 'belakan coba',
#  'belii': 'beli',
#  'belitiketdapatpulsa': 'beli tiket dapat pulsa',
#  'bellii': 'beli',
#  'belm': 'belum',
#  'belom': 'belum',
#  'ben': 'sudah',
#  'benar2': 'benar',
#  'benaroh': 'benar',
#  'benarpun': 'benar ',
#  'bencana': 'bencana',
#  'bene': 'benar',
#  'benee': 'benar',
#  'beneer': 'benar',
#  'beneeraann': 'benar',
#  'beneerr': 'benar',
#  'bener': 'benar',
#  'beneraann': 'benar',
#  'beneraan': 'benar',
#  'beneran': 'benar',
#  'benerann': 'benar',
#  'benerin': 'benar',
#  'benerr': 'benar',
#  'beningg': 'benar',
#  'benneerr': 'benar',
#  'benner': 'benar',
#  'bennerr': 'benar',
#  'benr': 'benar',
#  'bentuke': 'bentuk',
#  'beperiksa': 'berperiksa',
#  'beraa': 'berat',
#  'beraat': 'berat',
#  'beraatt': 'berat',
#  'beraktifts': 'beraktifitas',
#  'beraktivitas': 'beraktifitas',
#  'beranak': 'beranak',
#  'berantusias': 'berantusias',
#  'beratatt': 'berat',
#  'beratt': 'berat',
#  'berbahagia': 'bahagia',
#  'berbahayaa': 'berbahaya',
#  'berbg': 'berbagi',
#  'berbincang': 'berbincang',
#  'bercayaha': 'bercahaya',
#  'berduaan': 'berduaan',
#  'berhasill': 'berhasil',
#  'berhibanlah': 'berhijab',
#  'berhijab': 'berhijab',
#  'berhijaban': 'berhijab',
#  'berhijabnya': 'berhijab',
#  'berhijrah': 'hijrah',
#  'berhsill': 'berhasil',
#  'berikann': 'berikan',
#  'beriman': 'beriman',
#  'berisii': 'berisi',
#  'beritatimnas': 'berita timnah',
#  'berjam2': 'berjam',
#  'berjerawatt': 'berjerawat ',
#  'berjilbab': 'berjilbab',
#  'berkaat': 'berkat',
#  'berkaatt': 'berkat',
#  'berkahii': 'berkah',
#  'berkahmu': 'berkah',
#  'berkahshoppku': 'berkah shop',
#  'berkatt': 'berkat',
#  'berkkaat': 'berkat',
#  'berkkaatt': 'berkat',
#  'berkualitass': 'berkualitas',
#  'berkungjung': 'berkunjung',
#  'berkwalitas': 'berkualitas',
#  'berlipat2': 'berlipat',
#  'bermanfaatt': 'bermanfaat',
#  'bermerk': 'merk',
#  'berputarand': 'berputar',
#  'berraatt': 'berat',
#  'berrat': 'berat',
#  'berrsih': 'bersih',
#  'bersamayuuk': 'bersama',
#  'bershka': 'bersih',
#  'bersihh': 'bersih',
#  'bersihkan': 'bersih',
#  'bersiihh': 'bersih',
#  'berslh': 'bersalah',
#  'berturutdiscount': 'berturut discount',
#  'beruntunggnyaa': 'beruntung',
#  'beryayi': 'bernyanyi',
#  'mbesok': 'besok',
#  'besaar': 'besar',
#  'beesook': 'besok',
#  'besokk': 'besok',
#  'besok': 'besok',
#  'besarnta': 'besar',
#  'besuk': 'besuk',
#  'betapaa': 'betapa',
#  'betull': 'betul',
#  'betuull': 'betul',
#  'bgs': 'bagus',
#  'bgsan': 'bagus',
#  'bgts': 'banget',
#  'bgtt': 'banget',
#  'bgus': 'bagus',
#  'bgusan': 'bagus',
#  'bguz': 'bagus',
#  'bhes': 'bahas',
#  'bhs': 'bahasa',
#  'bhsa': 'bahasa',
#  'bia': 'biar',
#  'biarin': 'biar',
#  'biarkan': 'biar',
#  'biarlah': 'biar',
#  'biarpun': 'biar',
#  'biarr': 'biar',
#  'biasaa': 'biasa',
#  'biasalah': 'biasa',
#  'biasane': 'biasa',
#  'biasanya': 'biasa',
#  'biassaa': 'biasa',
#  'biisaa': 'biasa',
#  'bijak': 'bijak',
#  'bijaksana': 'bijak',
#  'bikiinn': 'bikin',
#  'bikin': 'bikin',
#  'bikinin': 'bikin',
#  'bikinn': 'bikin',
#  'bikkiinn': 'bikin',
#  'bilaang': 'bilang',
#  'bilangg': 'bilang',
#  'bincang2': 'bincang',
#  'bisaa': 'bisa',
#  'bisaamencerahkann': 'bisa mencerahkan',
#  'bisanya': 'bisanya',
#  'bismillahirahmanirahim': 'bismillahh',
#  'bismillahirohmanirohhim': 'bismillahh',
#  'bismillahirohmanirohim': 'bismillahh',
#  'bismillahmasa': 'bismillahh',
#  'bisnisdatabase': 'bisnis database',
#  'bisnisdirumah': 'bisnis rumah',
#  'bisnisonline': 'bisnis online',
#  'bisnispinkonveksi': 'bisnis pin konveksi',
#  'bisnistiket': 'bisnis tiket',
#  'bisnistiketpesawat': 'bisnis pesawat terbang',
#  'bisnistiketpesawatmurah': 'bisnis tiket pesawat terbang',
#  'bisnistiketpesawatonline': 'bisnis tike pesawat terbang',
#  'bissa': 'bisa',
#  'bissaa': 'bisa',
#  'bissmillahirohmanirrohim': 'bismillahh',
#  'bkan': 'bukan',
#  'bkas': 'bekas',
#  'bkin': 'bikin',
#  'bkl': 'bekal',
#  'blagu': 'belagu',
#  'blakang': 'belakang',
#  'blay': 'belay',
#  'bleh': 'boleh',
#  'blereng': 'belerang',
#  'bless': 'balas',
#  'blh': 'boleh',
#  'blik': 'balik',
#  'blink2': 'blik',
#  'bliss': 'blis',
#  'blja': 'belanja',
#  'blkang': 'belakang',
#  'blkg': 'belakang',
#  'blkng': 'belakang',
#  'bln': 'bulan',
#  'blng': 'bulan',
#  'blok': 'blok',
#  'blom': 'belum',
#  'bnang': 'benang',
#  'bncong': 'bencong',
#  'bneran': 'benar',
#  'bnerin': 'benar',
#  'bnerr2': 'benar',
#  'bnerr': 'benar',
#  'bnget': 'banget',
#  'bngett': 'banget',
#  'bnggeet': 'banget',
#  'bngtt': 'banget',
#  'bnib': 'bnib',
#  'bnr2': 'benar',
#  'bnyaak': 'bannyak',
#  'bnyakk': 'banyak',
#  'bodok': 'bodoh',
#  'bodok2': 'bodoh',
#  'bohongg': 'bohong',
#  'bojo2': 'istri',
#  'bokap': 'bapak',
#  'bolehh': 'boleh',
#  'bolh': 'boleh',
#  'bolng': 'bolong',
#  'bolong': 'bolong',
#  'bonusjudionline': 'bonus judi online',
#  'bonuss': 'bonus',
#  'bookingtanpa': 'booking tanpa',
#  'boongan': 'bohong',
#  'booss': 'bos',
#  'bosen': 'bosan',
#  'boskkuu': 'bos',
#  'bossque': 'bos',
#  'braa': 'bra',
#  'brakallah': 'barakallah',
#  'branded': 'band',
#  'brang': 'barang',
#  'brantah': 'berantah',
#  'brapa': 'berapa',
#  'brati': 'berarti',
#  'brbagi': 'berbagi',
#  'brcnda': 'bercanda',
#  'brgoyng': 'bergoyang',
#  'brikan': 'berikan',
#  'brkah': 'berkah',
#  'brkualitas': 'berkualitas',
#  'broh': 'bro',
#  'brp': 'berapa',
#  'brsnr': 'bersinar',
#  'brti': 'berarti',
#  'brubah': 'berubah',
#  'brusan': 'berurusan',
#  'brwnis': 'brownis',
#  'bsa': 'bisa',
#  'bsok': 'besok',
#  'bsra': 'besar',
#  'btul': 'betul',
#  'buahdiet': 'biah diet',
#  'buang2': 'buang',
#  'buanget': 'banget',
#  'buanyak': 'banyak',
#  'buat2': 'buat',
#  'buatt': 'buat',
#  'budayaa': 'budaya',
#  'bukaann': 'bukan',
#  'bukann': 'bukan',
#  'bukanne': 'bukan',
#  'bukannya': 'bukan',
#  'bukanyaa': 'bukan',
#  'bukittinggi': 'bukit tinggi',
#  'buktiin': 'bukti',
#  'buktikan': 'bukti',
#  'buktinyaa': 'bukti',
#  'bulanan': 'bulan',
#  'bulanjangan': 'bulan jangan',
#  'bulann': 'bulan',
#  'bulannya': 'bulan',
#  'bully': 'bully',
#  'buli': 'bully',
#  'bulli': 'bully',
#  'bullying': 'bully',
#  'buming': 'booming',
#  'bumingnya': 'booming',
#  'buru2': 'buru',
#  'buruann': 'buru',
#  'buruuaann': 'buru',
#  'busett': 'buset',
#  'business': 'bisnis',
#  'busuii': 'busui',
#  'buwat': 'buat',
#  'bwain': 'bawa',
#  'bwngt': 'banget',
#  'bwt': 'buat',
#  'byk': 'banyak',
#  'bbadaan': 'badan',
#  'bberapaa': 'berapa',
#  'bbnya': 'bb',
#  'bbrapa': 'berapa',
#  'bdan': 'badan',
#  'bday': 'badai',
#  'bdn': 'badan',
#  'bdua': 'berdua',
#  'bearaa': 'berapa',
#  'caari': 'cari',
#  'cadass': 'cadar',
#  'cakar2n': 'cakar',
#  'cakepan': 'cakep',
#  'candaa': 'canda',
#  'canggihh': 'canggih',
#  'cangkemu': 'mulut',
#  'cantek': 'cantik',
#  'cantiik': 'cantik',
#  'cantik2': 'cantik',
#  'cantikdy': 'cantik',
#  'cantiknyaa': 'cantik',
#  'cantikperkenalkan': 'cantik perkenalkan',
#  'cantlk': 'cantik',
#  'captionnya': 'caption',
#  'carapesan': 'cara pesan',
#  'carimodal': 'cari modal',
#  'casecustom': 'case custom',
#  'casinominimal': 'casinio nominal',
#  'casinoonline': 'casini online',
#  'cayank': 'sayang',
#  'ccuman': 'cuma',
#  'cebi': 'cebi',
#  'cebie': 'cebi',
#  'ceek': 'cek',
#  'cekk': 'cek',
#  'celldy': 'cell',
#  'celotehan': 'celotehan',
#  'cemooh': 'cemooh',
#  'cepaatt': 'cepat',
#  'cepatproses': 'cepat proses',
#  'cepet': 'cepat',
#  'cepetan': 'cepat',
#  'cepett': 'cepat',
#  'ceppaatt': 'cepat',
#  'ceraah': 'cerah',
#  'ceraahh': 'cerah',
#  'cerahh': 'cerah',
#  'cerdaassaa': 'cerdas',
#  'ceriaa': 'ceria',
#  'ceritakan': 'cerita',
#  'ceritane': 'cerita',
#  'ceritanya': 'cerita',
#  'ceritone': 'cerita',
#  'cerrah': 'cerah',
#  'cewe': 'cewek',
#  'check': 'cek',
#  'chek': 'cek',
#  'ciaapp': 'siap',
#  'cincinnya': 'cincin',
#  'cinlok': 'cinlok',
#  'cinta2an': 'cinta',
#  'cintahh': 'cinta',
#  'cintai': 'cinta',
#  'cintaku': 'cinta',
#  'cintamu': 'cinta',
#  'cipt': 'cip',
#  'cirikasnya': 'ciri khasnya',
#  'ciuman': 'ciuman',
#  'ckup': 'cukup',
#  'clana': 'celana',
#  'cliniknya': 'klinik',
#  'cma': 'Cuma',
#  'cmn': 'cuma',
#  'cntikk': 'cantik',
#  'cntiknya': 'cantik',
#  'coba2': 'coba',
#  'cobaa': 'coba',
#  'cobaiinn': 'coba',
#  'cobain': 'coba',
#  'cobbaa': 'coba',
#  'coii': 'coi',
#  'ckckck ': 'nan',
#  'cokelat': 'cokelat',
#  'coklat': 'cokelat',
#  'comennt': 'komentar',
#  'coment': 'komentar',
#  'commau': 'komentar',
#  'comment': 'komentar',
#  'complain': 'komplain',
#  'contact': 'kontak',
#  'contohnya': 'contoh',
#  'contone': 'contoh',
#  'cooba': 'coba',
#  'counteryuk': 'counter',
#  'cpat': 'cepat',
#  'cpe': 'capek',
#  'cpet': 'cepat',
#  'cpett': 'cepat',
#  'cpt': 'cepat',
#  'cra': 'cara',
#  'creamm': 'cream',
#  'creamrd': 'cream',
#  'crem': 'cream',
#  'cucubisa': 'cucu bisa',
#  'cukuplah': 'cukup',
#  'cukupp': 'cukup',
#  'cukuppoo': 'cukup',
#  'cumaa': 'cuma',
#  'cumaann': 'Cuma',
#  'cumann': 'Cuma',
#  'cumman': 'Cuma',
#  'custom2': 'custom',
#  'customer': 'customer',
#  'custumer': 'customer',
#  'cuumaan': 'cuma',
#  'cwe': 'cewek',
#  'cweet': 'sweet',
#  'cwek': 'cewek',
#  'cwo': 'cowok',
#  'cwok': 'cowok',
#  'daarii': 'dari',
#  'daan': 'dan',
#  'daann': 'dan',
#  'daappet': 'dapat',
#  'daarqu': 'darqu',
#  'daarrii': 'dari',
#  'daarul': 'darul',
#  'dach': 'nan',
#  'dadine': 'jadinya',
#  'daebak': 'daebak',
#  'daee': 'nan',
#  'dalaamm': 'dalam',
#  'dalamm': 'dalam',
#  'dalamm15': 'dalam',
#  'dallaamm': 'dalam',
#  'dallamm': 'dalam',
#  'dallam': 'dalam',
#  'dance2': 'dance',
#  'dancer': 'dance',
#  'dancernya': 'dance',
#  'dandananya': 'dandan',
#  'dangdutkoplo': 'dangdut koplo',
#  'dangdutt': 'dangdut',
#  'dankencang': 'dan kencang',
#  'dann': 'dan',
#  'dapatkn': 'dapatkan',
#  'dapatt': 'dapat',
#  'dapet': 'dapat',
#  'dapetin': 'dapat',
#  'daree': 'dare',
#  'dari0': 'dari',
#  'darii': 'dari',
#  'darikui': 'dari kui',
#  'daril': 'dari',
#  'darimana': 'darimana',
#  'darimpak': 'dari ',
#  'darling': 'darling',
#  'darrii': 'dari',
#  'darri': 'dari',
#  'dasyat': 'dahsyat',
#  'datengnya': 'datang',
#  'datng': 'datang',
#  'days': 'day',
#  'dblz': 'dibalas',
#  'dborong': 'diborong',
#  'ddaarii': 'dari',
#  'ddann': 'dan',
#  'ddarii': 'dari',
#  'ddi': 'di',
#  'ddmd': 'dmd',
#  'ddulu': 'dulu',
#  'degpelangsing': 'pelangsing',
#  'dengaan': 'dengan',
#  'dengaann': 'dengan',
#  'dengann': 'dengan',
#  'dengernya': 'dengar',
#  'dengn': 'dengan',
#  'desahin': 'desah',
#  'detoks': 'detoks',
#  'detox': 'detoks',
#  'dewee': 'sendiri',
#  'dfvtu': 'difoto',
#  'diajarin': 'diajar',
#  'diampeke': 'diam pake',
#  'diapain': 'diapain',
#  'dibales': 'dibalas',
#  'dibanggain': 'bangga',
#  'dibatalin': 'batal',
#  'dibawain': 'bawa',
#  'dibrantas': 'branta',
#  'didaftarin': 'daftar',
#  'didengerin': 'dengar',
#  'didengernya': 'dengar',
#  'didie': 'di diet',
#  'diem': 'diam pake',
#  'dietmax': 'diet maks',
#  'diett': 'diet',
#  'difollback': 'follow back',
#  'difollow': 'follow',
#  'digedein': 'besar',
#  'digitalmarketing': 'digital market',
#  'diig': 'di ig',
#  'dii': 'di',
#  'diinject': 'di inject',
#  'dijaminn': 'dijamin',
#  'dijamjn': 'dijamin',
#  'dijamnin': 'dijamin',
#  'dijkt': 'di jakarta',
#  'dijogja': 'di jogja',
#  'dijuallb': 'dijual',
#  'dikatain': 'katain',
#  'dikatainn': 'katain',
#  'dikecilin': 'kecil',
#  'dikenalin': 'kenal',
#  'dikenalinn': 'kenal',
#  'dikit2': 'sedikit',
#  'diladenin': 'ladini',
#  'diledekk': 'ledek',
#  'dilepasin': 'lepas',
#  'dilimpahkann': 'limpahkan',
#  'dimacem': 'macem',
#  'dimaksut': 'maksud',
#  'dimane': 'mane',
#  'dimanfaatin': 'manfaatin',
#  'dimna': 'dimana',
#  'dimonas': 'di monas',
#  'dimulaior': 'dimulai',
#  'dimulutt': 'di mulut',
#  'dinobarkan': 'di nobarkan',
#  'dinyanyiin': 'nyanyi',
#  'dioprasi': 'operasi',
#  'dipacarin': 'pacar',
#  'dipantura': 'pantura',
#  'dipkir': 'pikir',
#  'diplaystore': 'playstore',
#  'direcaman': 'rekaman',
#  'direekomendasiin': 'rekomendasi',
#  'direfil': 'refil',
#  'direk0mendasiikan': 'rekomendasi',
#  'diridhoi': 'rido',
#  'dirii': 'diri',
#  'dirikulying': 'diriku',
#  'disalah2in': 'salah',
#  'disalahin': 'salah',
#  'disaraniin': 'saran',
#  'disaranin': 'saran',
#  'disaraninn': 'saran',
#  'disekolahin': 'seklah',
#  'disembunyiin': 'sembunyi',
#  'disinii': 'disini',
#  'dismg': 'di semarang',
#  'distinguish': 'disting',
#  'distributorarenatiket': 'distributor',
#  'distro': 'distro',
#  'ditabokim': 'tabok',
#  'ditaipe': 'ditaipe',
#  'ditarik2x': 'ditarik',
#  'ditayangin': 'tayang',
#  'ditungguin': 'tunggu',
#  'diucapin': 'ucap',
#  'diundangg': 'undang',
#  'diupload': 'upload',
#  'diutamakandy': 'utama',
#  'divisihumaspolri': 'divisi humat polri',
#  'diwenehi': 'dikasih',
#  'dkasih': 'dikasih',
#  'dkt': 'dekat',
#  'dl': 'dulu',
#  'dllmau': 'dan lain lain mau',
#  'dllnya': 'dan lain lain',
#  'dlsk0n': 'diskon',
#  'dluu': 'dulu',
#  'dmmore': 'dm more',
#  'dmmurah': 'dm murah',
#  'doain': 'doain',
#  'doangg': 'saja',
#  'doank': 'saja',
#  'doesn': "does't",
#  'dokk': 'dokter',
#  'dokternyaa': 'dokter',
#  'dokterr': 'dokter',
#  'dollar': 'dollar',
#  'dongakno': 'doakan',
#  'donx': 'dong',
#  'dpat': 'dapat',
#  'dpatkan': 'dapat',
#  'dperiksa': 'diperiksa',
#  'dposit': 'deposit',
#  'drg': 'drg',
#  'drii': 'dari',
#  'drivera': 'drive',
#  'drmn': 'dari mana',
#  'dropsip': 'dropsip',
#  'drpd': 'dari  pada',
#  'dsare': 'share',
#  'dsitu': 'situ',
#  'dsn': 'sana',
#  'dstu': 'situ',
#  'dsuruh': 'suruh',
#  'dtrstv': 'ditranstv',
#  'dua2': 'dua',
#  'duaa': 'dua',
#  'dublok': 'dua blok',
#  'duek': 'duek',
#  'duitin': 'duit',
#  'dulu2': 'dulu',
#  'dulunyaa': 'dulu',
#  'duluu': 'dulu',
#  'durung': 'belum',
#  'duwe': 'punya',
#  'duwur': 'tinggi',
#  'dwe': 'sendiri',
#  'dwek': 'sendiri',
#  'dwet': 'duit',
#  'eeenak': 'enak',
#  'efeekknyaa': 'efek',
#  'efekk': 'efek',
#  'efeksampingg': 'efek samping',
#  'efektipp': 'efektif',
#  'eghisi': 'egisi',
#  'ehh': 'nan',
#  'ehiyaa': 'nan',
#  'ejekin': 'ejek',
#  'ejing': 'ejing',
#  'elegantt': 'elegan',
#  'elek': 'jelek',
#  'emaangg': 'memang',
#  'emaanngg': 'memang',
#  'emangg': 'memang',
#  'emanggtopp': 'memang top',
#  'emanng': 'memang',
#  'emgg': 'memang',
#  'emmaangg': 'memang',
#  'emmang': 'memang',
#  'emng': 'memang',
#  'emngg': 'memang',
#  'emvang': 'memang',
#  'enaakk': 'enak',
#  'enackan': 'enak',
#  'enake': 'enak',
#  'enakk': 'enak',
#  'endi': 'mana',
#  'endog': 'telur',
#  'endors': 'endors',
#  'endorse': 'endors',
#  'engak': 'tidak',
#  'enggaa': 'tidak',
#  'engko': 'nanti',
#  'enk': 'enak',
#  'entek': 'habis',
#  'entuk': 'dapat',
#  'even': 'even',
#  'event': 'even',
#  'eyke': 'saya',
#  'f0llow': 'follow',
#  'families': 'family',
#  'family': 'family',
#  'fansnya': 'fans',
#  'farmasik': 'farmasi',
#  'farmasims': 'farmasi',
#  'fashionherbaldijamin': 'fashion herbal dijamin',
#  'fashionkecantikan': 'fashion kecantikan',
#  'fasihonherbal': 'fasihon herbal',
#  'fasiltas': 'fasilitas',
#  'file2': 'file',
#  'filenya': 'file',
#  'filmbioskop': 'film  bioskop',
#  'filmkeren': 'film keren',
#  'filmnasional': 'film nasional',
#  'filmnetflix': 'film netflix',
#  'flekhitam': 'flek hitam',
#  'fllw': 'follow',
#  'flow': 'follow',
#  'fokuss': 'fokus',
#  'folback': 'follow back',
#  'foll': 'follow',
#  'follow': 'follow',
#  'follower': 'follow',
#  'followere': 'follow',
#  'followers': 'follow',
#  'followw': 'follow',
#  'folow': 'follow',
#  'folowers': 'follow',
#  'gaa': 'tidak',
#  'gaaminderr': 'tidak mider',
#  'gaanyangkaa': 'tidak sangka',
#  'gaak': 'tidak',
#  'gaakan': 'tidak akan',
#  'gaakk': 'tidak',
#  'gabahagian': 'tidak kebagian',
#  'gabakalan': 'tidak akan',
#  'gabikin': 'tidak bikin',
#  'gabuncit': 'tidak buncit',
#  'gabungnih': 'gabung',
#  'gabusa': 'tidak bisa',
#  'gacobain': 'tidak coba',
#  'gadgetnya': 'gadget',
#  'gadiapaapain': 'gadai',
#  'gakada': 'tidak ada',
#  'gakadakatamustahilkaloallahmenghendaki': 'tidak ada kata mustahil',
#  'gakk': 'tidak',
#  'gaksadar': 'tidak sadar',
#  'galacellbdgcek': 'gala cell',
#  'gamengganggu': 'tidak mengganggu',
#  'gaminderr': 'tidak minder',
#  'gaminndeer': 'tidak minder',
#  'gampaang': 'gampang',
#  'gamungkin': 'tidak mungkin',
#  'ganti2': 'ganti',
#  'gantiin': 'ganti',
#  'gantipolapikirshare': 'ganti pola pikir share',
#  'ganyangka': 'tidak sangka',
#  'ganyangkaa': 'tidak sangka',
#  'gapake': 'tidak pakai',
#  'gapercayasih': 'tidak percaya',
#  'gaperlu': 'tidak perlu',
#  'gapernah': 'tidak pernah',
#  'garaa': 'gara',
#  'garagara': 'gara',
#  'gariingg': 'garing',
#  'garudaindonesia': 'garuda indonesia',
#  'gasalah': 'tidak salah',
#  'gasalahh': 'tidak salah',
#  'gasuka': 'tidak suka',
#  'gatauu': 'tidak tahu',
#  ...}

# %%
with open("last_use.json", "w") as f:
    json.dump(dict_, f)

# %%
a = {'a':'s', 'f':'s','x':'x','c':'s'}
a = {'u':'s', 'w':'s','l':'x','g':'s'}
